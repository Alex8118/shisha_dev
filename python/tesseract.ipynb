# %%
try:
    from PIL import Image
except ImportError:
    import Image
import pytesseract

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract'

# %%
def to_string(link):
    print('текст с картинки: \n', pytesseract.image_to_string(link, lang='eng'))
    img = mpimg.imread(link)
    plt.imshow(img)
    plt.show()

# %%
to_string(link='test.jpg')
# Out:
# текст с картинки:
#  $ | FRESH
#
# _fumaxi | HOOKAH TOBACCO
